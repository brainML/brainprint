# %%
import cortex
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import scipy.io as sio

# %%
# local directory# local 
path = '/Users/lwehbe/Google Drive/'
# subject number
subject_num = 3
filename = os.path.join(path, 'subset_MEG.mat')


mat = sio.loadmat(filename)
data = mat['train_data']

# %%
data.shape
# Out:
# (6, 3713, 306, 20)

# %%
for i in [0,2,4]:
    plt.plot(np.all(data[i,:,:,1]==0,1))

# %%
for i in [1,3,5]:
    plt.plot(np.all(data[i,:,:,1]==0,1))

# %%
run_number = mat['storyind3'].ravel()
plt.plot(run_number);

# %%
##### HOW TO ZSCORE??? SHOULD WE DO IT BY SUBJECT TIME AND SENSOR OR JUST BY SUBJECT AND SENSOR? 
from scipy.stats import zscore
data = zscore(data,1)

# %%
labels = mat['labels']
labels = [l[0][0] for l in labels]

# %%
plt.imshow(data[0,0,:,:],aspect = 'auto',vmin = -0.5,vmax = 0.5)
plt.title(labels[0][0][0])

# %%
plt.imshow(data[2,0,:,:],aspect = 'auto',vmin = -0.5,vmax = 0.5)
plt.title(labels[0][0][0])

# %%
ind = [i for i in range(len(labels)) if labels[i]=='Harry']

# %%
ind
# Out:
# [0,
#  82,
#  277,
#  316,
#  432,
#  585,
#  744,
#  813,
#  947,
#  1057,
#  1135,
#  1308,
#  1340,
#  1377,
#  1401,
#  1510,
#  1531,
#  1566,
#  1594,
#  1631,
#  1807,
#  1936,
#  2185,
#  2292,
#  2422,
#  2710,
#  2827,
#  3060,
#  3128,
#  3291,
#  3561]

# %%
for i in ind:
    plt.figure()
    plt.imshow(data[2,i,:,:],aspect = 'auto')
    plt.title(labels[i])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
plt.imshow(np.mean(data[2,ind,:,:],0),aspect = 'auto',vmin = -0.5,vmax = 0.5)
plt.title(labels[i])

# %%
plt.imshow(np.mean(data[4,ind,:,:],0),aspect = 'auto',vmin = -0.5,vmax = 0.5)
plt.title(labels[i])

# %%
plt.imshow(np.mean(data[5,ind,:,:],0),aspect = 'auto',vmin = -0.5,vmax = 0.5)
plt.title(labels[i])
